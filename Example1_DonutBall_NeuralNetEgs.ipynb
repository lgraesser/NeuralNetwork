# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %run NeuralNet2.ipynb

# %%
train_x = pickle.load( open( "nn_donutballdata_train_x.pkl", "rb" ) )
train_y = pickle.load( open( "nn_donutballdata_train_y.pkl", "rb" ) )
test_x = pickle.load( open( "nn_donutballdata_test_x.pkl", "rb" ) )
test_y = pickle.load( open( "nn_donutballdata_test_y.pkl", "rb" ) )

# %% [markdown]
# ## A first neural network

# %%
net = NeuralNet((2,4,1), QuadraticCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables()
learning_rate = 0.1
batch_size = 10
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.12266 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.11829 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.11775 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 400 is 0.10985 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 600 is 0.06189 and accuracy is 83.07%
# Validation set accuracy is 81.99%
# Training cost in epoch 800 is 0.01606 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 1000 is 0.00488 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Final test cost is 0.00488
# Accuracy on training data is 100.00%, and accuracy on validation data is 100.00%

# %% [markdown]
# ## The network learns faster with different parameter initalizations

# %%
net = NeuralNet((2,4,1), QuadraticCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables_normalized()
learning_rate = 0.1
batch_size = 10
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.12502 and accuracy is 38.36%
# Validation set accuracy is 43.55%
# Training cost in epoch 0 is 0.11833 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.11628 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 400 is 0.07462 and accuracy is 82.57%
# Validation set accuracy is 81.99%
# Training cost in epoch 600 is 0.01344 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 800 is 0.00468 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 1000 is 0.00282 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Final test cost is 0.00282
# Accuracy on training data is 100.00%, and accuracy on validation data is 100.00%

# %%
net = NeuralNet((2,4,1), QuadraticCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables_alt()
learning_rate = 0.1
batch_size = 10
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.15348 and accuracy is 38.36%
# Validation set accuracy is 43.55%
# Training cost in epoch 0 is 0.11853 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.10995 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 400 is 0.06132 and accuracy is 83.07%
# Validation set accuracy is 84.14%
# Training cost in epoch 600 is 0.05697 and accuracy is 83.86%
# Validation set accuracy is 85.48%
# Training cost in epoch 800 is 0.01053 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 1000 is 0.00413 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Final test cost is 0.00413
# Accuracy on training data is 100.00%, and accuracy on validation data is 100.00%

# %% [markdown]
# ## Using the cross entropy cost function is faster still

# %%
net = NeuralNet((2,4,1), CrossEntropyCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables()
learning_rate = 0.1
batch_size = 10
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.68379 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.66710 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.07816 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 400 is 0.01530 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 600 is 0.00913 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 800 is 0.00669 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 1000 is 0.00535 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Final test cost is 0.00535
# Accuracy on training data is 100.00%, and accuracy on validation data is 100.00%

# %% [markdown]
# ## Increasing the batch size slows down learning
# - Conversely, smaller batches speed up learning, but a single epoch takes longer to execute

# %%
net = NeuralNet((2,4,1), CrossEntropyCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables()
learning_rate = 0.1
batch_size = 50
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.68379 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.66705 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.66441 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 400 is 0.64784 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 600 is 0.47859 and accuracy is 79.71%
# Validation set accuracy is 77.69%
# Training cost in epoch 800 is 0.33912 and accuracy is 83.14%
# Validation set accuracy is 83.33%
# Training cost in epoch 1000 is 0.09050 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Final test cost is 0.09050
# Accuracy on training data is 100.00%, and accuracy on validation data is 100.00%

# %%
net = NeuralNet((2,4,1), CrossEntropyCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables()
learning_rate = 0.1
batch_size = 100
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.68379 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.67111 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.66532 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 400 is 0.66451 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 600 is 0.66192 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 800 is 0.65121 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 1000 is 0.61767 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.61767
# Accuracy on training data is 61.64%, and accuracy on validation data is 56.45%

# %% [markdown]
# ## Combining normalized parameter initialization with the cross entropy cost is the fastest yet

# %%
net = NeuralNet((2,4,1), CrossEntropyCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables_normalized()
learning_rate = 0.1
batch_size = 10
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.69323 and accuracy is 38.36%
# Validation set accuracy is 43.55%
# Training cost in epoch 0 is 0.66674 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.03936 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 400 is 0.01330 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 600 is 0.00850 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 800 is 0.00639 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Training cost in epoch 1000 is 0.00519 and accuracy is 100.00%
# Validation set accuracy is 100.00%
# Final test cost is 0.00519
# Accuracy on training data is 100.00%, and accuracy on validation data is 100.00%

# %% [markdown]
# ## The ReLU activation function does not appear to improve the performance of such a small network
# - Parameter initializations have a significant effect on whether the network learns anything at all
# - A smaller learning rate is also needed to prevent the cost function from increasing and the performance delining during later epochs

# %%
net = NeuralNet((2,4,1), CrossEntropyCost, ReluActivation, SigmoidActivation)
net.initialize_variables()
learning_rate = 0.05
batch_size = 10
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.68150 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.66608 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.33417 and accuracy is 83.71%
# Validation set accuracy is 85.22%
# Training cost in epoch 400 is 0.32442 and accuracy is 83.93%
# Validation set accuracy is 84.68%
# Training cost in epoch 600 is 0.32051 and accuracy is 85.00%
# Validation set accuracy is 85.22%
# Training cost in epoch 800 is 0.31970 and accuracy is 85.50%
# Validation set accuracy is 86.29%
# Training cost in epoch 1000 is 0.31918 and accuracy is 85.00%
# Validation set accuracy is 85.48%
# Final test cost is 0.31918
# Accuracy on training data is 85.00%, and accuracy on validation data is 85.48%

# %%
net = NeuralNet((2,4,1), CrossEntropyCost, ReluActivation, SigmoidActivation)
net.initialize_variables_normalized()
learning_rate = 0.05
batch_size = 10
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 0.68787 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.66617 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.66578 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 400 is 0.66582 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 600 is 0.66576 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 800 is 0.66580 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 1000 is 0.66572 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.66572
# Accuracy on training data is 61.64%, and accuracy on validation data is 56.45%

# %%
net = NeuralNet((2,4,1), CrossEntropyCost, ReluActivation, SigmoidActivation)
net.initialize_variables_alt()
learning_rate = 0.05
batch_size = 10
lmda = 0
epochs = 1001
reporting_rate = 200
training_cost, valid_cost = \
    net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate, lmda, batch_size)
# Out:
# Training cost at start of training is 1.23085 and accuracy is 38.36%
# Validation set accuracy is 43.55%
# Training cost in epoch 0 is 0.66911 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 200 is 0.66568 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 400 is 0.66573 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 600 is 0.66568 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 800 is 0.66573 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 1000 is 0.66568 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.66568
# Accuracy on training data is 61.64%, and accuracy on validation data is 56.45%

# %% [markdown]
# ## Plotting the learning process
# - The next cell contains a set of functions for recording the results of a neural network as it learns, then plotting the results in stages

# %%
def network_predictions(net, train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate):
    train_results = []
    test_results = []
    training_cost_all = []
    valid_cost_all = []
    
    i = 6
    while(i>0):
        training_cost, valid_cost = net.SGD(train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate)
        print()
        training_cost_all.extend(training_cost)
        valid_cost_all.extend(valid_cost)

        prediction_train = net.predict(train_x)
        train_result = np.hstack((train_x, prediction_train))
        train_results.append(train_result)

        prediction_test = net.predict(test_x)
        test_result = np.hstack((test_x, prediction_test))
        test_results.append(test_result)
        i -= 1

    return train_results, test_results, training_cost_all, valid_cost_all
    
def plot_subfig(ax, data, title):
    positives = data[data[:,2]==1]
    negatives = data[data[:,2]==0]
    ax.scatter(positives[:,0], positives[:,1], s=20, alpha=0.5, c='r', marker="o", label='positive')
    ax.scatter(negatives[:,0], negatives[:,1], s=20, alpha=0.5, c='b', marker="o", label='negative')
    ax.legend(loc='upper left')
    ax.set_title(title)

def plot_subplotpair(fig, train_result, test_result, training_title, test_title):
    ax1 = fig.add_subplot(221)
    plot_subfig(ax1, train_result, training_title)
    ax2 = fig.add_subplot(222)
    plot_subfig(ax2, test_result, test_title)
    
def plot_all(num_results, train_results, test_results, training_titles, test_titles, name):
    for i in range(6):
        fig = plt.figure(figsize=(12,12))
        newname = name + '-' + str(i) +'.png'
        plot_subplotpair(fig, train_results[i], test_results[i], training_titles[i], test_titles[i])
        plt.savefig(newname, dpi=200)
    plt.show()

# %% [markdown]
# ### Example1: Network with the same set of hyperparamters as the first network.
# - Slow to learn: 960 epochs to achieve 100% accuracy

# %%
net = NeuralNet((2,4,1), QuadraticCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables()
learning_rate = 0.1
batch_size = 10
lmda = 0
epochs = 160
reporting_rate = 200

train_results, test_results, training_cost_all, valid_cost_all = \
                network_predictions(net, train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate)
training_titles = ["Training data: epoch 160","Training data: epoch 320","Training data: epoch 480",\
                  "Training data: epoch 640","Training data: epoch 800","Training data: epoch 960"]
test_titles = ["Test data: epoch 160","Test data: epoch 320","Test data: epoch 480",\
                  "Test data: epoch 640","Test data: epoch 800","Test data: epoch 960"]
name = 'DonutBall_slowlearning'
plot_all(6, train_results, test_results, training_titles, test_titles, name)
# Out:
# Training cost at start of training is 0.12266 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.11829 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.11795
# Accuracy on training data is 61.64%, and accuracy on validation data is 56.45%
#
# Training cost at start of training is 0.11795 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.11795 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.11561
# Accuracy on training data is 61.64%, and accuracy on validation data is 56.45%
#
# Training cost at start of training is 0.11561 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.11557 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.08883
# Accuracy on training data is 76.29%, and accuracy on validation data is 72.85%
#
# ...

# %% [markdown]
# ### Example2: Alternative setup, learns much faster
# - Learns much faster: 150 epochs to achieve 100% accuracy with the same batch size and learning rate

# %%
net = NeuralNet((2,4,1), CrossEntropyCost, SigmoidActivation, SigmoidActivation)
net.initialize_variables_normalized()
learning_rate = 0.1
batch_size = 10
lmda = 0
epochs = 25
reporting_rate = 200

train_results, test_results, training_cost_all, valid_cost_all = \
                network_predictions(net, train_x, train_y, test_x, test_y, learning_rate, epochs, reporting_rate)
training_titles = ["Training data: epoch 25","Training data: epoch 50","Training data: epoch 75",\
                  "Training data: epoch 100","Training data: epoch 125","Training data: epoch 150"]
test_titles = ["Test data: epoch 25","Test data: epoch 50","Test data: epoch 75",\
                  "Test data: epoch 100","Test data: epoch 125","Test data: epoch 150"]
name = 'DonutBall_fastlearning'
plot_all(6, train_results, test_results, training_titles, test_titles, name)
# Out:
# Training cost at start of training is 0.69323 and accuracy is 38.36%
# Validation set accuracy is 43.55%
# Training cost in epoch 0 is 0.66674 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.66345
# Accuracy on training data is 61.64%, and accuracy on validation data is 56.45%
#
# Training cost at start of training is 0.66345 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.66625 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.65456
# Accuracy on training data is 61.64%, and accuracy on validation data is 56.45%
#
# Training cost at start of training is 0.65456 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Training cost in epoch 0 is 0.65322 and accuracy is 61.64%
# Validation set accuracy is 56.45%
# Final test cost is 0.60378
# Accuracy on training data is 61.64%, and accuracy on validation data is 56.45%
#
# ...
