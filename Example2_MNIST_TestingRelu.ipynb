# %% [markdown]
# ## This notebook tests the performance of a ReLU hidden layer using different output layers, cost functions, learning rates, batch sizes, regularization rates and parameter initialization

# %%
import pickle
# %run NeuralNet2.ipynb
train_x = pickle.load(open("MNIST_train_x.pkl", 'rb'))
train_y = pickle.load(open("MNIST_train_y.pkl", 'rb'))
test_x = pickle.load(open("MNIST_test_x.pkl", 'rb'))
test_y = pickle.load(open("MNIST_test_y.pkl", 'rb'))
short_train_x = train_x[0:5000,:]
short_train_y = train_y[0:5000,:]

# %% [markdown]
# ## Testing ReLU with Quadratic Cost, Sigmoid output layer and different learning rates

# %%
net2 = NeuralNet((784,100,10), QuadraticCost, ReluActivation, SigmoidActivation)
net2.initialize_variables()
learning_rate = 1
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), QuadraticCost, ReluActivation, SigmoidActivation)
net2.initialize_variables()
learning_rate = 0.1
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), QuadraticCost, ReluActivation, SigmoidActivation)
net2.initialize_variables()
learning_rate = 0.01
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), QuadraticCost, ReluActivation, SigmoidActivation)
net2.initialize_variables()
learning_rate = 0.001
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)
# Out:
# /Users/lauragraesser/anaconda3/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:164: RuntimeWarning: overflow encountered in exp
# /Users/lauragraesser/anaconda3/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:405: RuntimeWarning: invalid value encountered in true_divide
# Training cost at start of training is 1.75843 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.50000 and accuracy is 9.58%
# Validation set accuracy is 9.80%
# Training cost in epoch 20 is 0.50000 and accuracy is 9.58%
# Validation set accuracy is 9.80%
# Training cost in epoch 40 is 0.50000 and accuracy is 9.58%
# Validation set accuracy is 9.80%
# Training cost in epoch 60 is 0.50000 and accuracy is 9.58%
# Validation set accuracy is 9.80%
# Final test cost is 0.50000
# Accuracy on training data is 9.58%, and accuracy on validation data is 9.80%
# Training cost at start of training is 1.75843 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.50000 and accuracy is 10.86%
# Validation set accuracy is 9.84%
# Training cost in epoch 20 is 0.50000 and accuracy is 10.86%
# Validation set accuracy is 9.84%
# Training cost in epoch 40 is 0.50000 and accuracy is 10.86%
# Validation set accuracy is 9.84%
# Training cost in epoch 60 is 0.50000 and accuracy is 10.86%
# Validation set accuracy is 9.84%
# Final test cost is 0.50000
# Accuracy on training data is 10.86%, and accuracy on validation data is 9.84%
# Training cost at start of training is 1.75843 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.46836 and accuracy is 21.82%
# Validation set accuracy is 22.86%
# Training cost in epoch 20 is 0.26617 and accuracy is 51.54%
# Validation set accuracy is 51.16%
# Training cost in epoch 40 is 0.22334 and accuracy is 58.86%
# Validation set accuracy is 57.86%
# Training cost in epoch 60 is 0.21766 and accuracy is 59.24%
# Validation set accuracy is 58.38%
# Final test cost is 0.21766
# Accuracy on training data is 59.24%, and accuracy on validation data is 58.38%
# Training cost at start of training is 1.75843 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.51378 and accuracy is 19.84%
# Validation set accuracy is 18.99%
# Training cost in epoch 20 is 0.39789 and accuracy is 33.12%
# Validation set accuracy is 34.21%
# Training cost in epoch 40 is 0.33410 and accuracy is 45.44%
# Validation set accuracy is 45.87%
# Training cost in epoch 60 is 0.29039 and accuracy is 50.72%
# Validation set accuracy is 50.14%
# Final test cost is 0.29039
# Accuracy on training data is 50.72%, and accuracy on validation data is 50.14%

# %% [markdown]
# ## Testing ReLU with Cross Entropy Cost, Sigmoid output layer and different learning rates

# %%
net2 = NeuralNet((784,100,10), CrossEntropyCost, ReluActivation, SigmoidActivation)
net2.initialize_variables()
learning_rate = 1
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), CrossEntropyCost, ReluActivation, SigmoidActivation)
net2.initialize_variables()
learning_rate = 0.1
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), CrossEntropyCost, ReluActivation, SigmoidActivation)
net2.initialize_variables()
learning_rate = 0.01
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), CrossEntropyCost, ReluActivation, SigmoidActivation)
net2.initialize_variables()
learning_rate = 0.001
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)
# Out:
# /Users/lauragraesser/anaconda3/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:113: RuntimeWarning: divide by zero encountered in log
# /Users/lauragraesser/anaconda3/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:113: RuntimeWarning: invalid value encountered in multiply
# /Users/lauragraesser/anaconda3/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:164: RuntimeWarning: overflow encountered in exp
# Training cost at start of training is nan and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 3.25412 and accuracy is 11.26%
# Validation set accuracy is 11.35%
# Training cost in epoch 20 is 3.24815 and accuracy is 10.70%
# Validation set accuracy is 9.82%
# Training cost in epoch 40 is 3.24807 and accuracy is 11.26%
# Validation set accuracy is 11.35%
# Training cost in epoch 60 is 3.24782 and accuracy is 11.26%
# Validation set accuracy is 11.35%
# Final test cost is 3.24782
# Accuracy on training data is 11.26%, and accuracy on validation data is 11.35%
# Training cost at start of training is nan and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 4.41449 and accuracy is 11.26%
# Validation set accuracy is 11.37%
# Training cost in epoch 20 is 3.24776 and accuracy is 11.26%
# Validation set accuracy is 11.37%
# Training cost in epoch 40 is 3.24769 and accuracy is 11.26%
# Validation set accuracy is 11.37%
# Training cost in epoch 60 is 3.24769 and accuracy is 11.26%
# Validation set accuracy is 11.37%
# Final test cost is 3.24769
# Accuracy on training data is 11.26%, and accuracy on validation data is 11.37%
# Training cost at start of training is nan and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 5.29567 and accuracy is 20.10%
# Validation set accuracy is 20.41%
# Training cost in epoch 20 is 3.44205 and accuracy is 20.46%
# Validation set accuracy is 20.49%
# Training cost in epoch 40 is 3.06226 and accuracy is 20.80%
# Validation set accuracy is 20.79%
# Training cost in epoch 60 is 2.95390 and accuracy is 20.96%
# Validation set accuracy is 20.78%
# Final test cost is 2.95390
# Accuracy on training data is 20.96%, and accuracy on validation data is 20.78%
# Training cost at start of training is nan and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 1.88397 and accuracy is 72.62%
# Validation set accuracy is 69.44%
# Training cost in epoch 20 is 0.29144 and accuracy is 96.32%
# Validation set accuracy is 89.36%
# Training cost in epoch 40 is 0.15191 and accuracy is 98.56%
# Validation set accuracy is 90.56%
# Training cost in epoch 60 is 0.09494 and accuracy is 99.12%
# Validation set accuracy is 91.28%
# Final test cost is 0.09494
# Accuracy on training data is 99.12%, and accuracy on validation data is 91.28%

# %% [markdown]
# ## Testing ReLU with Log Likelihood Cost, Softmax output layer and different learning rates

# %%
net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 1
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.1
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.01
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.001
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 200
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)
# Out:
# Training cost at start of training is 6.34394 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 2.32309 and accuracy is 11.26%
# Validation set accuracy is 11.34%
# Training cost in epoch 20 is 2.30026 and accuracy is 10.70%
# Validation set accuracy is 9.82%
# Training cost in epoch 40 is 2.30020 and accuracy is 11.26%
# Validation set accuracy is 11.34%
# Training cost in epoch 60 is 2.29991 and accuracy is 11.26%
# Validation set accuracy is 11.34%
# Final test cost is 2.29991
# Accuracy on training data is 11.26%, and accuracy on validation data is 11.34%
# Training cost at start of training is 6.34394 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 2.33213 and accuracy is 12.32%
# Validation set accuracy is 12.16%
# Training cost in epoch 20 is 2.29960 and accuracy is 11.28%
# Validation set accuracy is 11.35%
# Training cost in epoch 40 is 2.29931 and accuracy is 11.28%
# Validation set accuracy is 11.36%
# Training cost in epoch 60 is 2.29976 and accuracy is 11.26%
# Validation set accuracy is 11.34%
# Final test cost is 2.29976
# Accuracy on training data is 11.26%, and accuracy on validation data is 11.34%
# Training cost at start of training is 6.34394 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 1.66570 and accuracy is 37.44%
# Validation set accuracy is 34.19%
# Training cost in epoch 20 is 1.14545 and accuracy is 60.44%
# Validation set accuracy is 57.74%
# Training cost in epoch 40 is 1.07498 and accuracy is 61.92%
# Validation set accuracy is 59.02%
# Training cost in epoch 60 is 1.31763 and accuracy is 52.20%
# Validation set accuracy is 49.84%
# Final test cost is 1.31763
# Accuracy on training data is 52.20%, and accuracy on validation data is 49.84%
# Training cost at start of training is 6.34394 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.81058 and accuracy is 80.08%
# Validation set accuracy is 73.58%
# Training cost in epoch 20 is 0.04616 and accuracy is 99.06%
# Validation set accuracy is 89.13%
# Training cost in epoch 40 is 0.02886 and accuracy is 99.60%
# Validation set accuracy is 90.24%
# Training cost in epoch 60 is 0.02491 and accuracy is 99.50%
# Validation set accuracy is 90.54%
# Final test cost is 0.02491
# Accuracy on training data is 99.50%, and accuracy on validation data is 90.54%

# %% [markdown]
# ## Testing ReLU with Log Likelihood Cost, Softmax output layer, smaller batch sizes, learning rate shrunk with batch size

# %%
net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.0005
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 100
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.0003
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 50
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.0001
epochs = 61
reporting_rate = 20
lmda = 0
batch_size = 25
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)
# Out:
# Training cost at start of training is 6.34394 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.76373 and accuracy is 83.38%
# Validation set accuracy is 76.74%
# Training cost in epoch 20 is 0.03479 and accuracy is 99.24%
# Validation set accuracy is 88.76%
# Training cost in epoch 40 is 0.04037 and accuracy is 98.76%
# Validation set accuracy is 90.23%
# Training cost in epoch 60 is 0.03573 and accuracy is 99.12%
# Validation set accuracy is 90.69%
# Final test cost is 0.03573
# Accuracy on training data is 99.12%, and accuracy on validation data is 90.69%
# Training cost at start of training is 6.34394 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.67747 and accuracy is 85.22%
# Validation set accuracy is 79.84%
# Training cost in epoch 20 is 0.03248 and accuracy is 99.30%
# Validation set accuracy is 89.69%
# Training cost in epoch 40 is 0.03185 and accuracy is 99.08%
# Validation set accuracy is 90.61%
# Training cost in epoch 60 is 0.05318 and accuracy is 98.86%
# Validation set accuracy is 90.64%
# Final test cost is 0.05318
# Accuracy on training data is 98.86%, and accuracy on validation data is 90.64%
# Training cost at start of training is 6.34394 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.86001 and accuracy is 82.10%
# Validation set accuracy is 76.57%
# Training cost in epoch 20 is 0.03772 and accuracy is 99.32%
# Validation set accuracy is 89.06%
# Training cost in epoch 40 is 0.02162 and accuracy is 99.78%
# Validation set accuracy is 90.10%
# Training cost in epoch 60 is 0.03216 and accuracy is 99.22%
# Validation set accuracy is 90.44%
# Final test cost is 0.03216
# Accuracy on training data is 99.22%, and accuracy on validation data is 90.44%

# %% [markdown]
# ## Testing ReLU with Log Likelihood Cost, Softmax output layer, batch size = 100, learning rate = 0.0005, different regularization rates

# %%
net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.0005
epochs = 61
reporting_rate = 20
lmda = 1
batch_size = 100
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.0005
epochs = 61
reporting_rate = 20
lmda = 0.3
batch_size = 100
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.0005
epochs = 61
reporting_rate = 20
lmda = 0.1
batch_size = 100
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)
# Out:
# Training cost at start of training is 6.34762 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.76725 and accuracy is 83.38%
# Validation set accuracy is 76.74%
# Training cost in epoch 20 is 0.03822 and accuracy is 99.22%
# Validation set accuracy is 88.77%
# Training cost in epoch 40 is 0.04722 and accuracy is 98.74%
# Validation set accuracy is 90.09%
# Training cost in epoch 60 is 0.04333 and accuracy is 99.10%
# Validation set accuracy is 90.54%
# Final test cost is 0.04333
# Accuracy on training data is 99.10%, and accuracy on validation data is 90.54%
# Training cost at start of training is 6.34504 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.76479 and accuracy is 83.38%
# Validation set accuracy is 76.74%
# Training cost in epoch 20 is 0.03513 and accuracy is 99.36%
# Validation set accuracy is 88.76%
# Training cost in epoch 40 is 0.04014 and accuracy is 98.84%
# Validation set accuracy is 90.19%
# Training cost in epoch 60 is 0.03875 and accuracy is 99.14%
# Validation set accuracy is 90.44%
# Final test cost is 0.03875
# Accuracy on training data is 99.14%, and accuracy on validation data is 90.44%
# Training cost at start of training is 6.34430 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 0.76409 and accuracy is 83.38%
# Validation set accuracy is 76.74%
# Training cost in epoch 20 is 0.03487 and accuracy is 99.28%
# Validation set accuracy is 88.78%
# Training cost in epoch 40 is 0.03883 and accuracy is 98.86%
# Validation set accuracy is 90.21%
# Training cost in epoch 60 is 0.03056 and accuracy is 99.30%
# Validation set accuracy is 90.54%
# Final test cost is 0.03056
# Accuracy on training data is 99.30%, and accuracy on validation data is 90.54%

# %%
net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.0002
epochs = 61
reporting_rate = 20
lmda = 0.5
batch_size = 100
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)
# Out:
# Training cost at start of training is 6.34578 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 1.24265 and accuracy is 74.90%
# Validation set accuracy is 70.12%
# Training cost in epoch 20 is 0.09693 and accuracy is 97.96%
# Validation set accuracy is 87.16%
# Training cost in epoch 40 is 0.03535 and accuracy is 99.62%
# Validation set accuracy is 88.83%
# Training cost in epoch 60 is 0.02559 and accuracy is 99.80%
# Validation set accuracy is 89.64%
# Final test cost is 0.02559
# Accuracy on training data is 99.80%, and accuracy on validation data is 89.64%

# %% [markdown]
# ## Testing ReLU with Log Likelihood Cost, Softmax output layer, batch size = 100, learning rate = 0.0002, lmda = 0.3, different parameter initializations

# %%
net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables()
learning_rate = 0.0002
epochs = 61
reporting_rate = 20
lmda = 0.3
batch_size = 100
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables_normalized()
learning_rate = 0.0002
epochs = 61
reporting_rate = 20
lmda = 0.3
batch_size = 100
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)

net2 = NeuralNet((784,100,10), LogLikelihoodCost, ReluActivation, SoftmaxActivation)
net2.initialize_variables_alt()
learning_rate = 0.0002
epochs = 61
reporting_rate = 20
lmda = 0.5
batch_size = 100
training_cost, valid_cost = net2.SGD(short_train_x, short_train_y, test_x, test_y, learning_rate, \
        epochs, reporting_rate, lmda, batch_size, verbose=False)
# Out:
# Training cost at start of training is 6.34504 and accuracy is 6.34%
# Validation set accuracy is 6.35%
# Training cost in epoch 0 is 1.24194 and accuracy is 74.90%
# Validation set accuracy is 70.12%
# Training cost in epoch 20 is 0.09611 and accuracy is 97.96%
# Validation set accuracy is 87.18%
# Training cost in epoch 40 is 0.03467 and accuracy is 99.62%
# Validation set accuracy is 88.82%
# Training cost in epoch 60 is 0.02477 and accuracy is 99.80%
# Validation set accuracy is 89.65%
# Final test cost is 0.02477
# Accuracy on training data is 99.80%, and accuracy on validation data is 89.65%
# Training cost at start of training is 6.47415 and accuracy is 6.24%
# Validation set accuracy is 6.28%
# Training cost in epoch 0 is 1.66275 and accuracy is 74.38%
# Validation set accuracy is 69.44%
# Training cost in epoch 20 is 0.13157 and accuracy is 97.74%
# Validation set accuracy is 86.35%
# Training cost in epoch 40 is 0.04241 and accuracy is 99.28%
# Validation set accuracy is 88.02%
# Training cost in epoch 60 is 0.06824 and accuracy is 98.62%
# Validation set accuracy is 88.89%
# Final test cost is 0.06824
# Accuracy on training data is 98.62%, and accuracy on validation data is 88.89%
# Training cost at start of training is 6.25732 and accuracy is 8.96%
# Validation set accuracy is 9.46%
# Training cost in epoch 0 is 0.69294 and accuracy is 80.74%
# Validation set accuracy is 75.82%
# Training cost in epoch 20 is 0.04012 and accuracy is 99.48%
# Validation set accuracy is 89.80%
# Training cost in epoch 40 is 0.02513 and accuracy is 99.74%
# Validation set accuracy is 90.10%
# Training cost in epoch 60 is 0.02078 and accuracy is 99.84%
# Validation set accuracy is 90.46%
# Final test cost is 0.02078
# Accuracy on training data is 99.84%, and accuracy on validation data is 90.46%
